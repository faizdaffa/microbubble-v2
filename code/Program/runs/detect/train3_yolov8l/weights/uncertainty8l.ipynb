# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Result_test_model_8l.csv',sep=';')
data
# Out:
#            Image    r_mean     r_min     r_max    A_mean     A_min      A_max
# 0   IMG_0291.JPG  1.263411  0.770616  2.319702  5.014636  1.865632  16.904970
# 1   IMG_0292.JPG  1.383358  0.897966  1.926659  6.012000  2.533199  11.661642
# 2   IMG_0293.JPG  1.479303  0.756556  2.748318  6.874862  1.798177  23.729237
# 3   IMG_0294.JPG  1.433497  0.857096  2.425619  6.455701  2.307858  18.483965
# 4   IMG_0295.JPG  1.430613  1.085939  2.326611  6.429748  3.704764  17.005810
# 5   IMG_0296.JPG  1.367433  0.575718  2.075691  5.874377  1.041283  13.535531
# 6   IMG_0297.JPG  1.393107  0.468334  2.289435  6.097040  0.689068  16.466700
# 7   IMG_0298.JPG  1.447213  0.625275  2.382628  6.579829  1.228267  17.834555
# 8   IMG_0299.JPG  1.429486  0.607165  2.307867  6.419624  1.158146  16.732906
# 9   IMG_0300.JPG  1.414898  0.871985  2.638700  6.289268  2.388737  21.874083
# 10  IMG_0301.JPG  1.492942  0.675825  2.009996  7.002220  1.434888  12.692298
# 11  IMG_0302.JPG  1.343536  0.578007  2.493965  5.670854  1.049580  19.540274
# 12  IMG_0303.JPG  1.395488  0.621543  2.189199  6.117895  1.213648  15.056370
# 13  IMG_0304.JPG  1.450880  0.786731  2.117418  6.613221  1.944476  14.085199
# 14  IMG_0305.JPG  1.413389  0.944351  1.942577  6.275857  2.801671  11.855133
# 15  IMG_0306.JPG  1.363840  0.643414  1.959746  5.843551  1.300560  12.065609
# 16  IMG_0307.JPG  1.395254  0.589715  2.242591  6.115847  1.092531  15.799745
# 17  IMG_0308.JPG  1.374743  1.019447  1.842754  5.937356  3.264972  10.668039
# 18  IMG_0309.JPG  1.365271  0.639167  2.137951  5.855814  1.283449  14.359696
# 19  IMG_0310.JPG  1.382566  0.740554  2.585651  6.005121  1.722913  21.003403
# 20  IMG_0311.JPG  1.403712  0.619340  2.269330  6.190220  1.205058  16.178753

# %%
val = {
    'r_mean' : data['r_mean'],
    'r_min'  : data['r_min'],
    'r_max'  : data['r_max'],
    'A_mean' : data['A_mean'],
    'A_min'  : data['A_min'],
    'A_max'  : data['A_max']
}

# %%
# Assuming val is a dictionary with numeric values
n = 21

# Create lists to store the results
columns = ["Mean", "Standard Deviation", "Standard Error", "Uncertainty"]

data = []

# Append the header row to the data list
data.append(columns)

# Iterate over the keys in val
for i in val.keys():
    mean_value = round(val[i].mean(), 2)
    std_deviation = round(val[i].std(), 2)
    std_error = round((val[i].std() / np.sqrt(len(val[i]))), 2)
    u = round(np.sqrt((sum((val[i] - mean_value)**2)) / (n*(n-1))), 2)
    uncertainty = f"{mean_value} ± {u}"

    # Append the results to the data list
    data.append([mean_value, std_deviation, std_error, uncertainty])

# Transpose the data
transposed_data = list(zip(*data))

# Print the transposed table
for row in transposed_data:
    print("{:<20} {:<13} {:<13} {:<13} {:<13} {:<13} {}".format(*row))
# Out:
# Mean                 1.4           0.73          2.25          6.18          1.76          16.07
# Standard Deviation   0.05          0.16          0.25          0.43          0.8           3.52
# Standard Error       0.01          0.04          0.05          0.09          0.18          0.77
# Uncertainty          1.4 ± 0.01    0.73 ± 0.04   2.25 ± 0.05   6.18 ± 0.09   1.76 ± 0.18   16.07 ± 0.77

# %%
n = 21

# Create lists to store the results
columns = ["Mean", "Standard Deviation", "Standard Error", "Uncertainty"]

data = []

# Append the header row to the data list
data.append(columns)

# Iterate over the keys in val
for i in val.keys():
    mean_value = round(val[i].mean(), 2)
    std_deviation = round(val[i].std(), 2)
    std_error = round((val[i].std() / np.sqrt(len(val[i]))), 2)
    u = round(np.sqrt((sum((val[i] - mean_value)**2)) / (n*(n-1))), 2)
    uncertainty = f"{mean_value} ± {u}"

    # Append the results to the data list
    data.append([mean_value, std_deviation, std_error, uncertainty])

# Transpose the data
transposed_data = list(zip(*data))

# Print the transposed table
for row in transposed_data:
    print("{};{};{};{};{};{};{}".format(*row))
# Out:
# Mean;1.4;0.73;2.25;6.18;1.76;16.07
# Standard Deviation;0.05;0.16;0.25;0.43;0.8;3.52
# Standard Error;0.01;0.04;0.05;0.09;0.18;0.77
# Uncertainty;1.4 ± 0.01;0.73 ± 0.04;2.25 ± 0.05;6.18 ± 0.09;1.76 ± 0.18;16.07 ± 0.77
