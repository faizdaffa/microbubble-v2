# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Result_test_model_8n.csv',sep=';')
data
# Out:
#            Image    r_mean     r_min      r_max     A_mean     A_min  \
# 0   IMG_0291.JPG  1.318544  0.749112   2.617378   5.461840  1.762965
# 1   IMG_0292.JPG  1.381684  0.789193   1.998552   5.997460  1.956666
# 2   IMG_0293.JPG  2.907787  0.349801  19.686512  26.562876  0.384407
# 3   IMG_0294.JPG  1.429267  0.643894   2.334911   6.417659  1.302504
# 4   IMG_0295.JPG  1.388893  1.032688   2.277411   6.060203  3.350336
# 5   IMG_0296.JPG  1.453775  0.999552   2.397206   6.639635  3.138777
# 6   IMG_0297.JPG  1.424406  0.470942   2.275122   6.374080  0.696761
# 7   IMG_0298.JPG  1.450254  0.700478   2.310991   6.607514  1.541484
# 8   IMG_0299.JPG  1.470265  1.009620   2.193871   6.791113  3.202326
# 9   IMG_0300.JPG  1.439952  0.819561   2.452867   6.513972  2.110148
# 10  IMG_0301.JPG  1.465827  0.662671   2.020218   6.750175  1.379576
# 11  IMG_0302.JPG  1.343213  0.802060   2.436166   5.668126  2.020985
# 12  IMG_0303.JPG  1.442649  0.956816   2.290196   6.538393  2.876116
# 13  IMG_0304.JPG  1.514158  0.703573   2.275583   7.202651  1.555134
# 14  IMG_0305.JPG  1.457573  0.913062   2.691142   6.674371  2.619091
# 15  IMG_0306.JPG  1.455773  0.751359   2.155928   6.657899  1.773554
# 16  IMG_0307.JPG  1.459373  0.859572   2.238391   6.690864  2.321211
# 17  IMG_0308.JPG  1.448766  1.005597   2.433823   6.593960  3.176855
# 18  IMG_0309.JPG  1.366642  0.672424   2.067919   5.867581  1.420484
# 19  IMG_0310.JPG  1.355065  0.655956   2.588520   5.768592  1.351757
# 20  IMG_0311.JPG  1.427483  0.779920   2.303672   6.401647  1.910951
#
#           A_max
# 0     21.522007
# 1     12.548177
# 2   1217.551758
# 3     17.127367
# 4     16.294195
# 5     18.053467
# 6     16.261452
# 7     16.778240
# 8     15.120702
# 9     18.901566
# 10    12.821723
# 11    18.645058
# 12    16.477650
# 13    16.268045
# 14    22.752178
# 15    14.602199
# 16    15.740618
# 17    18.609201
# 18    13.434364
# 19    21.050034
# 20    16.672131

# %%
val = {
    'r_mean' : data['r_mean'],
    'r_min'  : data['r_min'],
    'r_max'  : data['r_max'],
    'A_mean' : data['A_mean'],
    'A_min'  : data['A_min'],
    'A_max'  : data['A_max']
}

# %%
# Assuming val is a dictionary with numeric values
n = 21

# Create lists to store the results
columns = ["Mean", "Standard Deviation", "Standard Error", "Uncertainty"]

data = []

# Append the header row to the data list
data.append(columns)

# Iterate over the keys in val
for i in val.keys():
    mean_value = round(val[i].mean(), 2)
    std_deviation = round(val[i].std(), 2)
    std_error = round((val[i].std() / np.sqrt(len(val[i]))), 2)
    u = round(np.sqrt((sum((val[i] - mean_value)**2)) / (n*(n-1))), 2)
    uncertainty = f"{mean_value} ± {u}"

    # Append the results to the data list
    data.append([mean_value, std_deviation, std_error, uncertainty])

# Transpose the data
transposed_data = list(zip(*data))

# Print the transposed table
for row in transposed_data:
    print("{:<20} {:<13} {:<13} {:<13} {:<13} {:<13} {}".format(*row))
# Out:
# Mean                 1.5           0.78          3.15          7.34          1.99          74.15
# Standard Deviation   0.33          0.18          3.79          4.42          0.83          262.0
# Standard Error       0.07          0.04          0.83          0.97          0.18          57.17
# Uncertainty          1.5 ± 0.07    0.78 ± 0.04   3.15 ± 0.83   7.34 ± 0.97   1.99 ± 0.18   74.15 ± 57.17

# %%
n = 21

# Create lists to store the results
columns = ["Mean", "Standard Deviation", "Standard Error", "Uncertainty"]

data = []

# Append the header row to the data list
data.append(columns)

# Iterate over the keys in val
for i in val.keys():
    mean_value = round(val[i].mean(), 2)
    std_deviation = round(val[i].std(), 2)
    std_error = round((val[i].std() / np.sqrt(len(val[i]))), 2)
    u = round(np.sqrt((sum((val[i] - mean_value)**2)) / (n*(n-1))), 2)
    uncertainty = f"{mean_value} ± {u}"

    # Append the results to the data list
    data.append([mean_value, std_deviation, std_error, uncertainty])

# Transpose the data
transposed_data = list(zip(*data))

# Print the transposed table
for row in transposed_data:
    print("{};{};{};{};{};{};{}".format(*row))
# Out:
# Mean;1.5;0.78;3.15;7.34;1.99;74.15
# Standard Deviation;0.33;0.18;3.79;4.42;0.83;262.0
# Standard Error;0.07;0.04;0.83;0.97;0.18;57.17
# Uncertainty;1.5 ± 0.07;0.78 ± 0.04;3.15 ± 0.83;7.34 ± 0.97;1.99 ± 0.18;74.15 ± 57.17
