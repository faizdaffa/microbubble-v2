# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Result_test_model_8x.csv',sep=';')
data
# Out:
#            Image    r_mean     r_min     r_max    A_mean     A_min      A_max
# 0   IMG_0291.JPG  1.246212  0.775823  2.384610  4.879030  1.890926  17.864243
# 1   IMG_0292.JPG  1.352551  0.946295  1.884213  5.747208  2.813213  11.153465
# 2   IMG_0293.JPG  1.352166  0.772192  2.051139  5.743941  1.873271  13.217219
# 3   IMG_0294.JPG  1.383993  0.839877  2.393557  6.017522  2.216058  17.998550
# 4   IMG_0295.JPG  1.382897  1.044752  2.252043  6.007997  3.429072  15.933206
# 5   IMG_0296.JPG  1.357195  0.634100  2.099630  5.786748  1.263180  13.849547
# 6   IMG_0297.JPG  1.481604  1.078665  2.346320  6.896265  3.655298  17.295158
# 7   IMG_0298.JPG  1.434585  0.659044  2.436649  6.465501  1.364518  18.652452
# 8   IMG_0299.JPG  1.393572  0.630799  2.429688  6.101109  1.250065  18.546022
# 9   IMG_0300.JPG  1.402284  0.828958  2.678522  6.177626  2.158813  22.539301
# 10  IMG_0301.JPG  1.487380  0.646486  2.034289  6.950143  1.313008  13.000957
# 11  IMG_0302.JPG  1.334436  0.648205  2.621891  5.594293  1.320001  21.596291
# 12  IMG_0303.JPG  1.400278  0.935081  2.222317  6.159965  2.746934  15.515366
# 13  IMG_0304.JPG  1.437561  0.724770  2.116482  6.492358  1.650253  14.072746
# 14  IMG_0305.JPG  1.418952  0.961199  1.925040  6.325360  2.902531  11.642050
# 15  IMG_0306.JPG  1.362727  0.649477  2.052681  5.834015  1.325188  13.237095
# 16  IMG_0307.JPG  1.432023  0.889471  2.175832  6.442436  2.485498  14.873063
# 17  IMG_0308.JPG  1.382427  1.011835  1.871271  6.003909  3.216392  11.000777
# 18  IMG_0309.JPG  1.358395  0.662287  1.985110  5.796985  1.377978  12.379951
# 19  IMG_0310.JPG  1.317834  0.692600  2.573307  5.455963  1.507005  20.803333
# 20  IMG_0311.JPG  1.434977  0.635272  2.346308  6.469041  1.267854  17.294975

# %%
val = {
    'r_mean' : data['r_mean'],
    'r_min'  : data['r_min'],
    'r_max'  : data['r_max'],
    'A_mean' : data['A_mean'],
    'A_min'  : data['A_min'],
    'A_max'  : data['A_max']
}

# %%
# Assuming val is a dictionary with numeric values
n = 21

# Create lists to store the results
columns = ["Mean", "Standard Deviation", "Standard Error", "Uncertainty"]

data = []

# Append the header row to the data list
data.append(columns)

# Iterate over the keys in val
for i in val.keys():
    mean_value = round(val[i].mean(), 2)
    std_deviation = round(val[i].std(), 2)
    std_error = round((val[i].std() / np.sqrt(len(val[i]))), 2)
    u = round(np.sqrt((sum((val[i] - mean_value)**2)) / (n*(n-1))), 2)
    uncertainty = f"{mean_value} ± {u}"

    # Append the results to the data list
    data.append([mean_value, std_deviation, std_error, uncertainty])

# Transpose the data
transposed_data = list(zip(*data))

# Print the transposed table
for row in transposed_data:
    print("{:<20} {:<13} {:<13} {:<13} {:<13} {:<13} {}".format(*row))
# Out:
# Mean                 1.39          0.79          2.23          6.06          2.05          15.83
# Standard Deviation   0.06          0.15          0.24          0.48          0.8           3.43
# Standard Error       0.01          0.03          0.05          0.1           0.17          0.75
# Uncertainty          1.39 ± 0.01   0.79 ± 0.03   2.23 ± 0.05   6.06 ± 0.1    2.05 ± 0.17   15.83 ± 0.75

# %%
n = 21

# Create lists to store the results
columns = ["Mean", "Standard Deviation", "Standard Error", "Uncertainty"]

data = []

# Append the header row to the data list
data.append(columns)

# Iterate over the keys in val
for i in val.keys():
    mean_value = round(val[i].mean(), 2)
    std_deviation = round(val[i].std(), 2)
    std_error = round((val[i].std() / np.sqrt(len(val[i]))), 2)
    u = round(np.sqrt((sum((val[i] - mean_value)**2)) / (n*(n-1))), 2)
    uncertainty = f"{mean_value} ± {u}"

    # Append the results to the data list
    data.append([mean_value, std_deviation, std_error, uncertainty])

# Transpose the data
transposed_data = list(zip(*data))

# Print the transposed table
for row in transposed_data:
    print("{};{};{};{};{};{};{}".format(*row))
# Out:
# Mean;1.39;0.79;2.23;6.06;2.05;15.83
# Standard Deviation;0.06;0.15;0.24;0.48;0.8;3.43
# Standard Error;0.01;0.03;0.05;0.1;0.17;0.75
# Uncertainty;1.39 ± 0.01;0.79 ± 0.03;2.23 ± 0.05;6.06 ± 0.1;2.05 ± 0.17;15.83 ± 0.75
